# %% [markdown]
# # 20.12 Критерий Lmax плоскослоистой модели
#
# > **Статус:** структурный каркас после реорганизации. Исполняемый расчёт ещё не перенесён или не проверен; наличие файла не является научным результатом.

# %% [markdown]
# ## Контракт этапа
#
# - **Серия:** `20`.
# - **Эксперимент или ветка:** Эксперименты 2–3.
# - **Происхождение:** Постановка `L_max` из `04`, `05` и `12`.
# - **Предусмотренные входы:** `20.02`, `20.10–20.11`, анатомическая и плоская модели, заранее заданная допустимая ошибка.
# - **Предусмотренный выход:** Индивидуальная либо проверенная диапазонная граница применимости; число 200 мм не переносить как результат.

# %% [markdown]
# ## Условия начала и завершения
#
# 1. До переноса кода установить владельца входных данных, единицы, состояние дыхания, прибор, монтаж и происхождение.
# 2. Локальные пути и субъектно-связанные данные хранить вне Git; в репозитории оставлять только схему конфигурации.
# 3. Все необходимые решения при неполных данных помечать как допущения, а неизвестные составляющие погрешности не заменять необоснованным распределением.
# 4. Этап считается выполненным только после проверки кода, физической интерпретации, происхождения результата и заранее заданного критерия продолжения.
