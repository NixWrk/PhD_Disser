# %% [markdown]
# # Указатель происхождения: 10_КТ_оценка_HU.ipynb
#
# > **Статус:** санифицированный указатель, а не копия исходного расчёта.
#
# - Исходный путь: Colab Notebooks/10_КТ_оценка_HU.ipynb.
# - Исходный коммит: 1ac7813654b59861e359cffe3ad40941baeab2d9.
# - Последняя объединённая активная версия перед разделением восстанавливается из
#   20.01_DICOM_QC_и_геометрия_тома.ipynb в коммите fff4d3a.
# - Контрольные суммы и ID ячеек находятся в
#   ../../MIGRATION_MANIFEST_2026-08-26.json.
# - Текущие владельцы функций: DICOM-QC —
#   ../../20.01_DICOM_QC_и_геометрия_тома.ipynb; регистрация ручных масок
#   Inobitec и электродов —
#   ../../20.02_Регистрация_Inobitec_и_электродов.ipynb; HU и доля воздуха —
#   ../../20.03_HU_и_доля_воздуха_в_лёгком.ipynb; электрические сценарии —
#   ../../20.04_Сценарии_электрических_свойств_лёгкого.ipynb.
# - Пороговая сегментация остаётся только историческим методом. Она не заменяет
#   каноническую ручную сегментацию Inobitec.
#
# Файл не содержит старых outputs, локальных путей или субъектно-связанных
# значений. Для восстановления исходной версии необходимо использовать
# Git-коммит и манифест. Этот указатель нельзя читать как вход активного расчёта.
