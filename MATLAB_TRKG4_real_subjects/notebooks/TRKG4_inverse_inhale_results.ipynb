# %% [markdown]
# > Техническая проверка 14.09.2026: этот файл содержит только текст и ссылки; расчётных ячеек нет. HTML пересобран, новый расчёт этим не выполнен.

# %% [markdown]
# # Отчёт включён в основную последовательность
#
# Полный ноутбук перенесён в [20.10 — КТ/FEM-локализация и сравнение моделей боковых сборок](../../Colab%20Notebooks/20.10_КТ_FEM_локализация_боковых_матриц_МГТУ.ipynb).
#
# [Читательская HTML-версия](../../Colab%20Notebooks/20.10_КТ_FEM_локализация_боковых_матриц_МГТУ.html).
#
# Этот файл служит указателем для прежних ссылок. Вычислений и результатов здесь нет. Генератор и MATLAB/Python-ядро остаются в прежней вычислительной ветке.
